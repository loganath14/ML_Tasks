# %%
import pandas as pd
import numpy as np

# %%
dataset=pd.read_csv("C:/Users/Loganath N/Downloads/Salary_Data.csv")

# %%
dataset
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
dataset.columns
# Out:
# Index(['YearsExperience', 'Salary'], dtype='object')

# %%
dataset.index
# Out:
# RangeIndex(start=0, stop=30, step=1)

# %%
dataset.describe()
# Out:
#        YearsExperience         Salary
# count        30.000000      30.000000
# mean          5.313333   76003.000000
# std           2.837888   27414.429785
# min           1.100000   37731.000000
# 25%           3.200000   56720.750000
# 50%           4.700000   65237.000000
# 75%           7.700000  100544.750000
# max          10.500000  122391.000000

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  30 non-null     float64
#  1   Salary           30 non-null     float64
# dtypes: float64(2)
# memory usage: 612.0 bytes

# %%
indep=dataset[["YearsExperience"]]
dep=dataset[["Salary"]]

# %%
indep
dep
# Out:
#       Salary
# 0    39343.0
# 1    46205.0
# 2    37731.0
# 3    43525.0
# 4    39891.0
# 5    56642.0
# 6    60150.0
# 7    54445.0
# 8    64445.0
# 9    57189.0
# 10   63218.0
# 11   55794.0
# 12   56957.0
# 13   57081.0
# 14   61111.0
# 15   67938.0
# 16   66029.0
# 17   83088.0
# 18   81363.0
# 19   93940.0
# 20   91738.0
# 21   98273.0
# 22  101302.0
# 23  113812.0
# 24  109431.0
# 25  105582.0
# 26  116969.0
# 27  112635.0
# 28  122391.0
# 29  121872.0

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(indep,dep)

# %%
plt.xlabel("Year of exprience")
# Out:
# Text(0.5, 0, 'Year of exprience')

# %%
plt.ylabel("Salary")
# Out:
# Text(0, 0.5, 'Salary')

# %%
plt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test=train_test_split(indep,dep,test_size=0.20)

# %%
X_train
# Out:
#     YearsExperience
# 12              4.0
# 6               3.0
# 29             10.5
# 25              9.0
# 11              4.0
# 14              4.5
# 20              6.8
# 22              7.9
# 16              5.1
# 24              8.7
# 23              8.2
# 27              9.6
# 17              5.3
# 8               3.2
# 0               1.1
# 7               3.2
# 21              7.1
# 26              9.5
# 3               2.0
# 10              3.9
# 9               3.7
# 18              5.9
# 28             10.3
# 4               2.2

# %%
X_test
# Out:
#     YearsExperience
# 13              4.1
# 1               1.3
# 5               2.9
# 2               1.5
# 15              4.9
# 19              6.0

# %%
Y_train
# Out:
#       Salary
# 12   56957.0
# 6    60150.0
# 29  121872.0
# 25  105582.0
# 11   55794.0
# 14   61111.0
# 20   91738.0
# 22  101302.0
# 16   66029.0
# 24  109431.0
# 23  113812.0
# 27  112635.0
# 17   83088.0
# 8    64445.0
# 0    39343.0
# 7    54445.0
# 21   98273.0
# 26  116969.0
# 3    43525.0
# 10   63218.0
# 9    57189.0
# 18   81363.0
# 28  122391.0
# 4    39891.0

# %%
Y_test
# Out:
#      Salary
# 13  57081.0
# 1   46205.0
# 5   56642.0
# 2   37731.0
# 15  67938.0
# 19  93940.0

# %%
from sklearn.linear_model import LinearRegression

# %%
regressor=LinearRegression()

# %%
regressor.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
Y_pred=regressor.predict(X_test)

# %%
Y_pred
# Out:
# array([[63995.24718998],
#        [37268.9993281 ],
#        [52541.14096346],
#        [39178.01703252],
#        [71631.31800765],
#        [82130.91538196]])

# %%
from sklearn.metrics import r2_score

# %%
r_score=r2_score(Y_test,Y_pred)

# %%
r_score
# Out:
# 0.8439982103359283
